# %% [markdown]
# <a href="https://colab.research.google.com/github/pranuk050-pixel/Pyspark_Programming/blob/main/26_08_26Spark_Hadoop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
spark:- distributed data processing engine/framework build on JAVA

JAVA
Scala --> native language
Python
R

master and slave node architecture


HADOOP MAPREDUCE:-
---------------------
table --> where -> select

read --> map   -> write intermediate data to disk --> reduce --> write the result to disk

DISK I/O happens frequently  ---> risky job

SPARK:-
-------
read --> process --> process --> process  --> final data


RAM  --> SPARK
ROM  --> AWS S3, Azure ADSL Gen2, DB,



Spark works with batch and streaming/realtime data as well


IPL  --> Hotstar(2balls faster than other channel)     Sony Liv



Spark components:-
1. Spark core(RDD)
2. Spark SQL(DataFrame)
3. Spark Streaming
4. Spark ML
5. Spark GraphQL


======================

cluster --> collection of nodes/machines(RAM and ROM)


Spark is 100X faster than Hadoop MapReduce


Spark works on lazy evolution --> until an action triggers no transformation will execute.

transformations:-
----------------
select
where
group by
order by
drop
add
join


actions:-
---------
show()
count()
collect()
write()
take()
first()


data process in 2 ways
1. RDD   --> SparkContext
2. DF(SQL) -->SparkSession
